# %% [markdown]
# # Chapter 4 Analyzing tabular data with pyspark
#
# This chapter cover:
#
# - Reading delimited data into a PySpark data frame
# - Understanding how PySpark represents tabular data in a data frame
# - Ingesting and exploring tabular or relational data
# - Selecting, manipulating, renaming, and deleting columns in a data frame
# - Summarizing data frames for quick exploration

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# change the account name to your email account
account='sli'

# define a root path to access the data in the DataAnalysisWithPythonAndPySpark
root_path='/net/clusterhn/home/'+account+'/isa460/Data/'

spark = (SparkSession.builder.appName("Analyzing tabluar data")
        .config("spark.port.maxRetries", "100")
        .getOrCreate())

# confiture the log level (defaulty is WWARN)
spark.sparkContext.setLogLevel('ERROR')
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/09/19 14:31:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4046. Attempting port 4047.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4047. Attempting port 4048.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4048. Attempting port 4049.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4049. Attempting port 4050.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4050. Attempting port 4051.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4051. Attempting port 4052.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4052. Attempting port 4053.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4053. Attempting port 4054.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4054. Attempting port 4055.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4055. Attempting port 4056.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4056. Attempting port 4057.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4057. Attempting port 4058.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4058. Attempting port 4059.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4059. Attempting port 4060.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4060. Attempting port 4061.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4061. Attempting port 4062.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4062. Attempting port 4063.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4063. Attempting port 4064.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4064. Attempting port 4065.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4065. Attempting port 4066.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4066. Attempting port 4067.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4067. Attempting port 4068.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4068. Attempting port 4069.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4069. Attempting port 4070.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4070. Attempting port 4071.
# 23/09/19 14:31:32 WARN Utils: Service 'SparkUI' could not bind on port 4071. Attempting port 4072.

# %%
# import data from a list of lists

my_grocery_list=[
    ["Banana", 2, 1.74],
    ["Apple", 4, 2.04],
    ["Carrot", 1, 1.09],
    ["cake", 1, 10.99]
]

# create a Dataframe based on the list

df=spark.createDataFrame(my_grocery_list, ["Item", "Quantity", "Price"])

df.printSchema()
# Out:
# root
#  |-- Item: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- Price: double (nullable = true)

# %% [markdown]
# ## import data from a csv file
#
# For this exercise, we’ll use some open data from the government of Canada, more specifically the CRTC (Canadian Radio-Television and Telecommunications Commission). Every broadcaster is mandated to provide a complete log of the programs and commercials showcased to the Canadian public. This gives us a lot of potential questions to answer, but we’ll select just one:
# **What are the channels with the greatest and least proportion of commercials?**
#
# You can download the [file](http://mng.bz/y4YJ) on the Canada Open Data portal ; select the BroadcastLogs_2018_Q3_M8 file. The file is 994 MB to download, which might be too large, depending on your computer. The book’s repository contains a sample of the data under the data/broadcast_logs directory, which you can use in place of the original file. You also need to download the Data Dictionary in .doc form, as well as the Reference Tables zip file, unzipping them into a ReferenceTables directory in data/ broadcast_logs. Once again, the examples assume that the data is downloaded under data/broadcast_logs and that PySpark is launched from the root of the repository.

# %%
import os

directory=root_path+'/broadcast_logs/'

logs=spark.read.csv(os.path.join(directory, "BroadcastLogs_2018_Q3_M8_sample.CSV"),
                                 sep="|",
                                 header=True,
                                 inferSchema=True,
                                 timestampFormat="yyyy-MM-dd",)

# %%
logs.printSchema()
# Out:
# root
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)

# %% [markdown]
# ## Exploring the shape of our data universe
#
# ![Figure 4.4](https://raw.githubusercontent.com/Suhong88/ISA460_Fall2023/main/images/Figure%204.4.png)

# %% [markdown]
# ## The basics of data manipulation: Selecting, dropping, renaming, ordering, diagnosing

# %% [markdown]
# ### Select columns

# %%
logs.select("BroadcastLogID", "LogServiceID", "LogDate").show(5, False)
# Out:
# +--------------+------------+----------+
# |BroadcastLogID|LogServiceID|LogDate   |
# +--------------+------------+----------+
# |1196192316    |3157        |2018-08-01|
# |1196192317    |3157        |2018-08-01|
# |1196192318    |3157        |2018-08-01|
# |1196192319    |3157        |2018-08-01|
# |1196192320    |3157        |2018-08-01|
# +--------------+------------+----------+
# only showing top 5 rows

# %%
# four ways of selecting columns
# Using the string to column conversion
logs.select("BroadCastLogID", "LogServiceID", "LogDate")

# use * to unpack a list
logs.select(*["BroadCastLogID", "LogServiceID", "LogDate"])
 
# Passing the column object explicitly
logs.select(
    F.col("BroadCastLogID"), F.col("LogServiceID"), F.col("LogDate")
)
logs.select(
    *[F.col("BroadCastLogID"), F.col("LogServiceID"), F.col("LogDate")]
)
# Out:
# DataFrame[BroadCastLogID: int, LogServiceID: int, LogDate: date]

# %%
# for a dataframe with a lot of columns, we can slice the columns into groups to display them by small groups

import numpy as np

group_size=5

column_split=np.array_split(logs.columns, len(logs.columns)//group_size)

print(column_split)
# Out:
# [array(['BroadcastLogID', 'LogServiceID', 'LogDate', 'SequenceNO',
#        'AudienceTargetAgeID'], dtype='<U22'), array(['AudienceTargetEthnicID', 'CategoryID', 'ClosedCaptionID',
#        'CountryOfOriginID', 'DubDramaCreditID'], dtype='<U22'), array(['EthnicProgramID', 'ProductionSourceID', 'ProgramClassID',
#        'FilmClassificationID', 'ExhibitionID'], dtype='<U22'), array(['Duration', 'EndTime', 'LogEntryDate', 'ProductionNO',
#        'ProgramTitle'], dtype='<U22'), array(['StartTime', 'Subtitle', 'NetworkAffiliationID',
#        'SpecialAttentionID', 'BroadcastOriginPointID'], dtype='<U22'), array(['CompositionID', 'Producer1', 'Producer2', 'Language1',
#        'Language2'], dtype='<U22')]

# %%
for X in column_split:
    logs.select(*X).show(5,False)
# Out:
# +--------------+------------+----------+----------+-------------------+
# |BroadcastLogID|LogServiceID|LogDate   |SequenceNO|AudienceTargetAgeID|
# +--------------+------------+----------+----------+-------------------+
# |1196192316    |3157        |2018-08-01|1         |4                  |
# |1196192317    |3157        |2018-08-01|2         |null               |
# |1196192318    |3157        |2018-08-01|3         |null               |
# |1196192319    |3157        |2018-08-01|4         |null               |
# |1196192320    |3157        |2018-08-01|5         |null               |
# +--------------+------------+----------+----------+-------------------+
# only showing top 5 rows
#
# +----------------------+----------+---------------+-----------------+----------------+
# |AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|
# +----------------------+----------+---------------+-----------------+----------------+
# |null                  |13        |3              |3                |null            |
# |null                  |null      |1              |null             |null            |
# |null                  |null      |1              |null             |null            |
# |null                  |null      |1              |null             |null            |
# |null                  |null      |1              |null             |null            |
# +----------------------+----------+---------------+-----------------+----------------+
# only showing top 5 rows
#
# +---------------+------------------+--------------+--------------------+------------+
# |EthnicProgramID|ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|
# +---------------+------------------+--------------+--------------------+------------+
# |null           |10                |19            |null                |2           |
# |null           |null              |20            |null                |null        |
# |null           |null              |3             |null                |null        |
# |null           |null              |3             |null                |null        |
# |null           |null              |3             |null                |null        |
# +---------------+------------------+--------------+--------------------+------------+
# only showing top 5 rows
#
# +----------------+----------------+------------+------------+-------------------------------------------+
# |Duration        |EndTime         |LogEntryDate|ProductionNO|ProgramTitle                               |
# +----------------+----------------+------------+------------+-------------------------------------------+
# |02:00:00.0000000|08:00:00.0000000|2018-08-01  |A39082      |Newlywed and Dead                          |
# |00:00:30.0000000|06:13:45.0000000|2018-08-01  |null        |15-SPECIALTY CHANNELS-Canadian Generic     |
# |00:00:15.0000000|06:14:00.0000000|2018-08-01  |null        |3-PROCTER & GAMBLE INC-Anti-Perspirant 3rd |
# |00:00:15.0000000|06:14:15.0000000|2018-08-01  |null        |12-CREDIT KARMA-Bank/Credit Union/Trust 3rd|
# |00:00:15.0000000|06:14:30.0000000|2018-08-01  |null        |3-L'OREAL CANADA-Hair Products 3rd         |
# +----------------+----------------+------------+------------+-------------------------------------------+
# only showing top 5 rows
#
# +----------------+--------+--------------------+------------------+----------------------+
# |StartTime       |Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|
# +----------------+--------+--------------------+------------------+----------------------+
# |06:00:00.0000000|null    |null                |null              |null                  |
# |06:13:15.0000000|null    |null                |null              |null                  |
# |06:13:45.0000000|null    |null                |null              |null                  |
# |06:14:00.0000000|null    |null                |null              |null                  |
# |06:14:15.0000000|null    |null                |null              |null                  |
# +----------------+--------+--------------------+------------------+----------------------+
# only showing top 5 rows
#
# +-------------+---------+---------+---------+---------+
# |CompositionID|Producer1|Producer2|Language1|Language2|
# +-------------+---------+---------+---------+---------+
# |null         |null     |null     |94       |null     |
# |null         |null     |null     |null     |null     |
# |null         |null     |null     |null     |null     |
# |null         |null     |null     |null     |null     |
# |null         |null     |null     |null     |null     |
# +-------------+---------+---------+---------+---------+
# only showing top 5 rows

# %%
# create a function to display sample records by a group of columns

import numpy as np

def display_columns_byGroup(df, group_size):
    column_split=np.array_split(df.columns, len(df.columns)//group_size)
    for X in column_split:
        df.select(*X).show(5,False)

# %% [markdown]
# ### Drop columns

# %%
logs1 = logs.drop("BroadcastLogID", "SequenceNO")

# Testing if we effectively got rid of the columns
 
print("BroadcastLogID" in logs1.columns)  # => False
print("SequenceNO" in logs1.columns)  # => False
# Out:
# False
# False

# %%
# instead drop, you can also select the ones you want to keep
logs1 = logs.select(
    *[x for x in logs.columns if x not in ["BroadcastLogID", "SequenceNO"]]
)

# %% [markdown]
# ### Create new columns

# %%
# create a column showing duration in seconds

logs.select("Duration").show(5)
# Out:
# +----------------+
# |        Duration|
# +----------------+
# |02:00:00.0000000|
# |00:00:30.0000000|
# |00:00:15.0000000|
# |00:00:15.0000000|
# |00:00:15.0000000|
# +----------------+
# only showing top 5 rows

# %%
logs.select(F.col("Duration")).dtypes
# Out:
# [('Duration', 'string')]

# %%
# step 1: extract hours, minutes and seconds

logs.select(F.col("Duration").substr(1,2).cast("int").alias("dur_hours"), 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes"),
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).show()
# Out:
# +---------+-----------+-----------+
# |dur_hours|dur_minutes|dur_seconds|
# +---------+-----------+-----------+
# |        2|          0|          0|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         30|
# |        0|          0|         30|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          0|         15|
# |        0|          1|          0|
# |        0|          0|         15|
# +---------+-----------+-----------+
# only showing top 20 rows

# %%
# step 2. merge all fields into one

logs.select(F.col("Duration"), (F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).alias("Duration_seconds")).show(5)
# Out:
# +----------------+----------------+
# |        Duration|Duration_seconds|
# +----------------+----------------+
# |02:00:00.0000000|            7200|
# |00:00:30.0000000|              30|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# +----------------+----------------+
# only showing top 5 rows

# %%
# create a new column for duration in seconds

logs.withColumn("Duration_seconds", F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds")).select("Duration", "Duration_seconds").show(5)
# Out:
# +----------------+----------------+
# |        Duration|Duration_seconds|
# +----------------+----------------+
# |02:00:00.0000000|            7200|
# |00:00:30.0000000|              30|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# |00:00:15.0000000|              15|
# +----------------+----------------+
# only showing top 5 rows

# %%
# print Schema. Why I do not see the new column?
logs.printSchema()
# Out:
# root
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)

# %%
logs1=logs.withColumn("Duration_seconds", F.col("Duration").substr(1,2).cast("int").alias("dur_hours")*60*60+ 
            F.col("Duration").substr(4,2).cast("int").alias("dur_minutes")*60+
            F.col("Duration").substr(7,2).cast("int").alias("dur_seconds"))

# %% [markdown]
# ![Warning](https://raw.githubusercontent.com/Suhong88/ISA460_Fall2023/main/images/Figure%204.5.png)

# %% [markdown]
# ### Rename and Reordering columns

# %%
logs2=logs1.withColumnRenamed("Duration_seconds", "duration_seconds")
logs2.columns
# Out:
# ['BroadcastLogID',
#  'LogServiceID',
#  'LogDate',
#  'SequenceNO',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'Duration',
#  'EndTime',
#  'LogEntryDate',
#  'ProductionNO',
#  'ProgramTitle',
#  'StartTime',
#  'Subtitle',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Producer1',
#  'Producer2',
#  'Language1',
#  'Language2',
#  'duration_seconds']

# %%
# change all columns to lower case

logs.toDF(*[x.lower() for x in logs.columns])
# Out:
# DataFrame[broadcastlogid: int, logserviceid: int, logdate: date, sequenceno: int, audiencetargetageid: int, audiencetargetethnicid: int, categoryid: int, closedcaptionid: int, countryoforiginid: int, dubdramacreditid: int, ethnicprogramid: int, productionsourceid: int, programclassid: int, filmclassificationid: int, exhibitionid: int, duration: string, endtime: string, logentrydate: date, productionno: string, programtitle: string, starttime: string, subtitle: string, networkaffiliationid: int, specialattentionid: int, broadcastoriginpointid: int, compositionid: int, producer1: string, producer2: string, language1: int, language2: int]

# %%
# order all columns in alphabetical order

logs.select(sorted(logs.columns)).printSchema()

# store the result into a new dataframe

#logs1=logs.select(sorted(logs.columns))
# Out:
# root
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- BroadcastLogID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- ProgramClassID: integer (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- SequenceNO: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)

# %% [markdown]
# ### Diagnosing a data frame with describe() and summary()

# %%
#logs.describe().show()

# for a dataframe with a lot of column, we can describe it one by one

for i in logs.columns:
    logs.select(i).describe().show()
# Out:
# +-------+--------------------+
# |summary|      BroadcastLogID|
# +-------+--------------------+
# |  count|              238945|
# |   mean|1.2168651122760174E9|
# | stddev|1.4969134241431728E7|
# |    min|          1195788151|
# |    max|          1249431576|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      LogServiceID|
# +-------+------------------+
# |  count|            238945|
# |   mean| 3450.890284375065|
# | stddev|199.50673962554765|
# |    min|              3157|
# |    max|              3925|
# +-------+------------------+
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    max|
# +-------+
#
# +-------+-----------------+
# |summary|       SequenceNO|
# +-------+-----------------+
# |  count|           238945|
# |   mean|466.3855824562138|
# | stddev|311.5109104839786|
# |    min|                1|
# |    max|             1463|
# +-------+-----------------+
#
# +-------+-------------------+
# |summary|AudienceTargetAgeID|
# +-------+-------------------+
# |  count|              16112|
# |   mean| 3.4929245283018866|
# | stddev| 1.0415963394745125|
# |    min|                  1|
# |    max|                  4|
# +-------+-------------------+
#
# +-------+----------------------+
# |summary|AudienceTargetEthnicID|
# +-------+----------------------+
# |  count|                  1710|
# |   mean|    120.56432748538012|
# | stddev|      71.9869405943613|
# |    min|                     4|
# |    max|                   337|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|        CategoryID|
# +-------+------------------+
# |  count|             25506|
# |   mean|18.485297577040697|
# | stddev|  9.65585225202084|
# |    min|                 1|
# |    max|                29|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|    ClosedCaptionID|
# +-------+-------------------+
# |  count|             224117|
# |   mean| 1.0316174141185184|
# | stddev|0.24947032900378968|
# |    min|                  1|
# |    max|                  3|
# +-------+-------------------+
#
# +-------+------------------+
# |summary| CountryOfOriginID|
# +-------+------------------+
# |  count|             17822|
# |   mean|  4.06390977443609|
# | stddev|2.6159675821007333|
# |    min|                 2|
# |    max|                11|
# +-------+------------------+
#
# +-------+------------------+
# |summary|  DubDramaCreditID|
# +-------+------------------+
# |  count|               263|
# |   mean|5.1254752851711025|
# | stddev| 3.451329711438564|
# |    min|                 1|
# |    max|                10|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  EthnicProgramID|
# +-------+-----------------+
# |  count|             1895|
# |   mean|4.316622691292876|
# | stddev|2.296642145680029|
# |    min|                1|
# |    max|                6|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|ProductionSourceID|
# +-------+------------------+
# |  count|             16223|
# |   mean|11.193737286568453|
# | stddev| 6.079022239331342|
# |    min|                 1|
# |    max|                19|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|   ProgramClassID|
# +-------+-----------------+
# |  count|           238945|
# |   mean| 8.49341061750612|
# | stddev|7.902116846905775|
# |    min|                3|
# |    max|               30|
# +-------+-----------------+
#
# +-------+--------------------+
# |summary|FilmClassificationID|
# +-------+--------------------+
# |  count|                1885|
# |   mean|   1.953315649867374|
# | stddev|  1.6420515263133837|
# |    min|                   1|
# |    max|                   8|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      ExhibitionID|
# +-------+------------------+
# |  count|              9263|
# |   mean|  4.52067364784627|
# | stddev|1.4418772626833438|
# |    min|                 1|
# |    max|                 8|
# +-------+------------------+
#
# +-------+----------------+
# |summary|        Duration|
# +-------+----------------+
# |  count|          236724|
# |   mean|            null|
# | stddev|            null|
# |    min|00:00:01.0000000|
# |    max|06:30:09.0000000|
# +-------+----------------+
#
# +-------+----------------+
# |summary|         EndTime|
# +-------+----------------+
# |  count|          169979|
# |   mean|            null|
# | stddev|            null|
# |    min|00:00:00.0000000|
# |    max|23:59:59.0000000|
# +-------+----------------+
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    max|
# +-------+
#
# +-------+------------------+
# |summary|      ProductionNO|
# +-------+------------------+
# |  count|              3519|
# |   mean| 35710.61538461538|
# | stddev|3749.1340008607654|
# |    min|            030641|
# |    max|            c34183|
# +-------+------------------+
#
# +-------+------------------+
# |summary|      ProgramTitle|
# +-------+------------------+
# |  count|            238703|
# |   mean|            1999.0|
# | stddev|              null|
# |    min|  !NO 5PM A ID(:5)|
# |    max|�t� avec Jo�l 2/Un|
# +-------+------------------+
#
# +-------+----------------+
# |summary|       StartTime|
# +-------+----------------+
# |  count|          238945|
# |   mean|            null|
# | stddev|            null|
# |    min|00:00:00.0000000|
# |    max|23:59:59.0000000|
# +-------+----------------+
#
# +-------+--------------------+
# |summary|            Subtitle|
# +-------+--------------------+
# |  count|               15468|
# |   mean|   3463.573913043478|
# | stddev|  16251.272419144227|
# |    min|                #001|
# |    max|�tre dans le trou...|
# +-------+--------------------+
#
# +-------+--------------------+
# |summary|NetworkAffiliationID|
# +-------+--------------------+
# |  count|              108807|
# |   mean|   6.082200593711802|
# | stddev|   2.990848675228532|
# |    min|                   1|
# |    max|                   9|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|SpecialAttentionID|
# +-------+------------------+
# |  count|              2395|
# |   mean| 1.704384133611691|
# | stddev| 0.539463503486969|
# |    min|                 1|
# |    max|                 3|
# +-------+------------------+
#
# +-------+----------------------+
# |summary|BroadcastOriginPointID|
# +-------+----------------------+
# |  count|                  9978|
# |   mean|    2.1390058127881337|
# | stddev|    0.9323192037553322|
# |    min|                     1|
# |    max|                     3|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|     CompositionID|
# +-------+------------------+
# |  count|              9978|
# |   mean|3.4141110442974543|
# | stddev|0.9338603403654625|
# |    min|                 1|
# |    max|                 4|
# +-------+------------------+
#
# +-------+---------+
# |summary|Producer1|
# +-------+---------+
# |  count|     2607|
# |   mean|     null|
# | stddev|     null|
# |    min|      AMI|
# |    max|   VISION|
# +-------+---------+
#
# +-------+---------+
# |summary|Producer2|
# +-------+---------+
# |  count|       38|
# |   mean|     null|
# | stddev|     null|
# |    min|    NEWSW|
# |    max|       QC|
# +-------+---------+
#
# +-------+------------------+
# |summary|         Language1|
# +-------+------------------+
# |  count|             12586|
# |   mean|101.75377403464167|
# | stddev| 45.68403685468215|
# |    min|                94|
# |    max|               437|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language2|
# +-------+------------------+
# |  count|              2629|
# |   mean|175.49334347660707|
# | stddev|  86.0360379288395|
# |    min|                 3|
# |    max|               438|
# +-------+------------------+

# %%
# return numerical columns

numColumns=[item for item, type in logs.dtypes if type=='int']

numColumns
# Out:
# ['BroadcastLogID',
#  'LogServiceID',
#  'SequenceNO',
#  'AudienceTargetAgeID',
#  'AudienceTargetEthnicID',
#  'CategoryID',
#  'ClosedCaptionID',
#  'CountryOfOriginID',
#  'DubDramaCreditID',
#  'EthnicProgramID',
#  'ProductionSourceID',
#  'ProgramClassID',
#  'FilmClassificationID',
#  'ExhibitionID',
#  'NetworkAffiliationID',
#  'SpecialAttentionID',
#  'BroadcastOriginPointID',
#  'CompositionID',
#  'Language1',
#  'Language2']

# %%
# apply describe to numerical columns
for i in numColumns:
   logs.select(i).describe().show()
# Out:
# +-------+--------------------+
# |summary|      BroadcastLogID|
# +-------+--------------------+
# |  count|              238945|
# |   mean|1.2168651122760174E9|
# | stddev|1.4969134241431728E7|
# |    min|          1195788151|
# |    max|          1249431576|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      LogServiceID|
# +-------+------------------+
# |  count|            238945|
# |   mean| 3450.890284375065|
# | stddev|199.50673962554765|
# |    min|              3157|
# |    max|              3925|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|       SequenceNO|
# +-------+-----------------+
# |  count|           238945|
# |   mean|466.3855824562138|
# | stddev|311.5109104839786|
# |    min|                1|
# |    max|             1463|
# +-------+-----------------+
#
# +-------+-------------------+
# |summary|AudienceTargetAgeID|
# +-------+-------------------+
# |  count|              16112|
# |   mean| 3.4929245283018866|
# | stddev| 1.0415963394745125|
# |    min|                  1|
# |    max|                  4|
# +-------+-------------------+
#
# +-------+----------------------+
# |summary|AudienceTargetEthnicID|
# +-------+----------------------+
# |  count|                  1710|
# |   mean|    120.56432748538012|
# | stddev|      71.9869405943613|
# |    min|                     4|
# |    max|                   337|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|        CategoryID|
# +-------+------------------+
# |  count|             25506|
# |   mean|18.485297577040697|
# | stddev|  9.65585225202084|
# |    min|                 1|
# |    max|                29|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|    ClosedCaptionID|
# +-------+-------------------+
# |  count|             224117|
# |   mean| 1.0316174141185184|
# | stddev|0.24947032900378968|
# |    min|                  1|
# |    max|                  3|
# +-------+-------------------+
#
# +-------+------------------+
# |summary| CountryOfOriginID|
# +-------+------------------+
# |  count|             17822|
# |   mean|  4.06390977443609|
# | stddev|2.6159675821007333|
# |    min|                 2|
# |    max|                11|
# +-------+------------------+
#
# +-------+------------------+
# |summary|  DubDramaCreditID|
# +-------+------------------+
# |  count|               263|
# |   mean|5.1254752851711025|
# | stddev| 3.451329711438564|
# |    min|                 1|
# |    max|                10|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  EthnicProgramID|
# +-------+-----------------+
# |  count|             1895|
# |   mean|4.316622691292876|
# | stddev|2.296642145680029|
# |    min|                1|
# |    max|                6|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|ProductionSourceID|
# +-------+------------------+
# |  count|             16223|
# |   mean|11.193737286568453|
# | stddev| 6.079022239331342|
# |    min|                 1|
# |    max|                19|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|   ProgramClassID|
# +-------+-----------------+
# |  count|           238945|
# |   mean| 8.49341061750612|
# | stddev|7.902116846905775|
# |    min|                3|
# |    max|               30|
# +-------+-----------------+
#
# +-------+--------------------+
# |summary|FilmClassificationID|
# +-------+--------------------+
# |  count|                1885|
# |   mean|   1.953315649867374|
# | stddev|  1.6420515263133837|
# |    min|                   1|
# |    max|                   8|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      ExhibitionID|
# +-------+------------------+
# |  count|              9263|
# |   mean|  4.52067364784627|
# | stddev|1.4418772626833438|
# |    min|                 1|
# |    max|                 8|
# +-------+------------------+
#
# +-------+--------------------+
# |summary|NetworkAffiliationID|
# +-------+--------------------+
# |  count|              108807|
# |   mean|   6.082200593711802|
# | stddev|   2.990848675228532|
# |    min|                   1|
# |    max|                   9|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|SpecialAttentionID|
# +-------+------------------+
# |  count|              2395|
# |   mean| 1.704384133611691|
# | stddev| 0.539463503486969|
# |    min|                 1|
# |    max|                 3|
# +-------+------------------+
#
# +-------+----------------------+
# |summary|BroadcastOriginPointID|
# +-------+----------------------+
# |  count|                  9978|
# |   mean|    2.1390058127881337|
# | stddev|    0.9323192037553322|
# |    min|                     1|
# |    max|                     3|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|     CompositionID|
# +-------+------------------+
# |  count|              9978|
# |   mean|3.4141110442974543|
# | stddev|0.9338603403654625|
# |    min|                 1|
# |    max|                 4|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language1|
# +-------+------------------+
# |  count|             12586|
# |   mean|101.75377403464167|
# | stddev| 45.68403685468215|
# |    min|                94|
# |    max|               437|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language2|
# +-------+------------------+
# |  count|              2629|
# |   mean|175.49334347660707|
# | stddev|  86.0360379288395|
# |    min|                 3|
# |    max|               438|
# +-------+------------------+

# %%
# apply summary to numerical columns
for i in numColumns:
   logs.select(i).summary().show()
# Out:
# +-------+--------------------+
# |summary|      BroadcastLogID|
# +-------+--------------------+
# |  count|              238945|
# |   mean|1.2168651122760174E9|
# | stddev|1.4969134241431728E7|
# |    min|          1195788151|
# |    25%|          1204679721|
# |    50%|          1213242708|
# |    75%|          1226220083|
# |    max|          1249431576|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      LogServiceID|
# +-------+------------------+
# |  count|            238945|
# |   mean| 3450.890284375065|
# | stddev|199.50673962554765|
# |    min|              3157|
# |    25%|              3287|
# |    50%|              3379|
# |    75%|              3627|
# |    max|              3925|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|       SequenceNO|
# +-------+-----------------+
# |  count|           238945|
# |   mean|466.3855824562138|
# | stddev|311.5109104839786|
# |    min|                1|
# |    25%|              201|
# |    50%|              428|
# |    75%|              699|
# |    max|             1463|
# +-------+-----------------+
#
# +-------+-------------------+
# |summary|AudienceTargetAgeID|
# +-------+-------------------+
# |  count|              16112|
# |   mean| 3.4929245283018866|
# | stddev| 1.0415963394745125|
# |    min|                  1|
# |    25%|                  4|
# |    50%|                  4|
# |    75%|                  4|
# |    max|                  4|
# +-------+-------------------+
#
# +-------+----------------------+
# |summary|AudienceTargetEthnicID|
# +-------+----------------------+
# |  count|                  1710|
# |   mean|    120.56432748538012|
# | stddev|      71.9869405943613|
# |    min|                     4|
# |    25%|                    74|
# |    50%|                    95|
# |    75%|                   136|
# |    max|                   337|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|        CategoryID|
# +-------+------------------+
# |  count|             25506|
# |   mean|18.485297577040697|
# | stddev|  9.65585225202084|
# |    min|                 1|
# |    25%|                11|
# |    50%|                24|
# |    75%|                26|
# |    max|                29|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|    ClosedCaptionID|
# +-------+-------------------+
# |  count|             224117|
# |   mean| 1.0316174141185184|
# | stddev|0.24947032900378968|
# |    min|                  1|
# |    25%|                  1|
# |    50%|                  1|
# |    75%|                  1|
# |    max|                  3|
# +-------+-------------------+
#
# +-------+------------------+
# |summary| CountryOfOriginID|
# +-------+------------------+
# |  count|             17822|
# |   mean|  4.06390977443609|
# | stddev|2.6159675821007333|
# |    min|                 2|
# |    25%|                 2|
# |    50%|                 3|
# |    75%|                 5|
# |    max|                11|
# +-------+------------------+
#
# +-------+------------------+
# |summary|  DubDramaCreditID|
# +-------+------------------+
# |  count|               263|
# |   mean|5.1254752851711025|
# | stddev| 3.451329711438564|
# |    min|                 1|
# |    25%|                 2|
# |    50%|                 4|
# |    75%|                10|
# |    max|                10|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|  EthnicProgramID|
# +-------+-----------------+
# |  count|             1895|
# |   mean|4.316622691292876|
# | stddev|2.296642145680029|
# |    min|                1|
# |    25%|                1|
# |    50%|                6|
# |    75%|                6|
# |    max|                6|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|ProductionSourceID|
# +-------+------------------+
# |  count|             16223|
# |   mean|11.193737286568453|
# | stddev| 6.079022239331342|
# |    min|                 1|
# |    25%|                 7|
# |    50%|                12|
# |    75%|                16|
# |    max|                19|
# +-------+------------------+
#
# +-------+-----------------+
# |summary|   ProgramClassID|
# +-------+-----------------+
# |  count|           238945|
# |   mean| 8.49341061750612|
# | stddev|7.902116846905775|
# |    min|                3|
# |    25%|                3|
# |    50%|                3|
# |    75%|               19|
# |    max|               30|
# +-------+-----------------+
#
# +-------+--------------------+
# |summary|FilmClassificationID|
# +-------+--------------------+
# |  count|                1885|
# |   mean|   1.953315649867374|
# | stddev|  1.6420515263133837|
# |    min|                   1|
# |    25%|                   1|
# |    50%|                   1|
# |    75%|                   2|
# |    max|                   8|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|      ExhibitionID|
# +-------+------------------+
# |  count|              9263|
# |   mean|  4.52067364784627|
# | stddev|1.4418772626833438|
# |    min|                 1|
# |    25%|                 4|
# |    50%|                 5|
# |    75%|                 5|
# |    max|                 8|
# +-------+------------------+
#
# +-------+--------------------+
# |summary|NetworkAffiliationID|
# +-------+--------------------+
# |  count|              108807|
# |   mean|   6.082200593711802|
# | stddev|   2.990848675228532|
# |    min|                   1|
# |    25%|                   5|
# |    50%|                   6|
# |    75%|                   9|
# |    max|                   9|
# +-------+--------------------+
#
# +-------+------------------+
# |summary|SpecialAttentionID|
# +-------+------------------+
# |  count|              2395|
# |   mean| 1.704384133611691|
# | stddev| 0.539463503486969|
# |    min|                 1|
# |    25%|                 1|
# |    50%|                 2|
# |    75%|                 2|
# |    max|                 3|
# +-------+------------------+
#
# +-------+----------------------+
# |summary|BroadcastOriginPointID|
# +-------+----------------------+
# |  count|                  9978|
# |   mean|    2.1390058127881337|
# | stddev|    0.9323192037553322|
# |    min|                     1|
# |    25%|                     1|
# |    50%|                     3|
# |    75%|                     3|
# |    max|                     3|
# +-------+----------------------+
#
# +-------+------------------+
# |summary|     CompositionID|
# +-------+------------------+
# |  count|              9978|
# |   mean|3.4141110442974543|
# | stddev|0.9338603403654625|
# |    min|                 1|
# |    25%|                 3|
# |    50%|                 4|
# |    75%|                 4|
# |    max|                 4|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language1|
# +-------+------------------+
# |  count|             12586|
# |   mean|101.75377403464167|
# | stddev| 45.68403685468215|
# |    min|                94|
# |    25%|                94|
# |    50%|                94|
# |    75%|                94|
# |    max|               437|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Language2|
# +-------+------------------+
# |  count|              2629|
# |   mean|175.49334347660707|
# | stddev|  86.0360379288395|
# |    min|                 3|
# |    25%|               134|
# |    50%|               151|
# |    75%|               259|
# |    max|               438|
# +-------+------------------+
